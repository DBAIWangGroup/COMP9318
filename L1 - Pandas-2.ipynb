# %% [markdown]
# # Pivot Table on Pandas
#
# In this notebook, we focus on the `pivot_table` feature of `pandas`.

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv('./asset/sydney_housing_market.txt', sep='\t')
df.head()
# Out:
#       suburb       council   type  distance_to_CBD      value  sold
# 0   Turrella      Rockdale  house              9.9  $839,676     17
# 1   Sydenham  Marrickville  house              7.4  $845,771     21
# 2  St Peters  Marrickville  house              6.9  $920,169     50
# 3      Tempe  Marrickville  house              8.3  $921,390     59
# 4   Waterloo        Sydney  house              4.7  $937,316     11

# %% [markdown]
# # Pivot Table

# %% [markdown]
# In order to build up a pivot table, we must specify an index.

# %%
pd.pivot_table(df, index=['type'])
# Out:
#        distance_to_CBD    sold       value
# type
# house            6.585   69.20  1024662.90
# unit             6.280  108.55   585739.05

# %% [markdown]
# Note that the default aggregation function is `np.mean`. We can specify the aggregation function in the `aggfunc` parameter, as shown below.

# %%
pd.pivot_table(df, index=['type'], aggfunc={'distance_to_CBD':np.mean, 'sold':np.sum})
# Out:
#        distance_to_CBD  sold
# type
# house            6.585  1384
# unit             6.280  2171

# %% [markdown]
# For simplicity, we will stick with the default aggregation function.
#
# We also want to see *value*, but we need to change it into floats first

# %%
df['value']=df['value'].replace('[\$,]','',regex=True).astype(float)
pd.pivot_table(df, index=['type'])
# Out:
#        distance_to_CBD    sold       value
# type
# house            6.585   69.20  1024662.90
# unit             6.280  108.55   585739.05

# %% [markdown]
# We could also choose more than one column as index

# %%
pd.pivot_table(df, index=['type','council'])
# Out:
#                     distance_to_CBD        sold         value
# type  council
# house Ashfield             7.600000   79.500000  1.101914e+06
#       Botany Bay           8.200000   29.000000  1.090744e+06
#       Canada Bay           9.200000   15.000000  1.036064e+06
#       Canterbury           9.100000   36.000000  1.066214e+06
#       Leichhardt           5.200000  225.000000  1.076623e+06
#       Marrickville         6.742857   81.285714  9.933390e+05
#       Rockdale             9.900000   17.000000  8.396760e+05
#       Sydney               4.616667   55.666667  1.037789e+06
# unit  Ashfield             7.233333  109.666667  5.933117e+05
#       Botany Bay           8.200000   56.000000  4.844870e+05
#       Burwood              8.400000   43.000000  6.059270e+05
#       Canterbury           9.100000   15.000000  5.930810e+05
#       Lane Cove            7.000000  220.000000  6.112070e+05
#       Marrickville         6.550000   87.333333  5.929137e+05
#       Randwick             5.200000   53.000000  5.778140e+05
#       Ryde                 7.900000  139.000000  5.729230e+05
#       Sydney               3.760000  158.400000  5.863850e+05

# %% [markdown]
# ```columns``` provide an additional way to segment the data

# %%
pd.pivot_table(df, index=['council'], columns=['type'])
# Out:
#              distance_to_CBD                   value                 \
# type                   house      unit         house           unit
# council
# Ashfield            7.600000  7.233333  1.101914e+06  593311.666667
# Botany Bay          8.200000  8.200000  1.090744e+06  484487.000000
# Burwood                  NaN  8.400000           NaN  605927.000000
# Canada Bay          9.200000       NaN  1.036064e+06            NaN
# Canterbury          9.100000  9.100000  1.066214e+06  593081.000000
# Lane Cove                NaN  7.000000           NaN  611207.000000
# Leichhardt          5.200000       NaN  1.076623e+06            NaN
# Marrickville        6.742857  6.550000  9.933390e+05  592913.666667
# Randwick                 NaN  5.200000           NaN  577814.000000
# Rockdale            9.900000       NaN  8.396760e+05            NaN
# Ryde                     NaN  7.900000           NaN  572923.000000
# Sydney              4.616667  3.760000  1.037789e+06  586385.000000
#
#                     sold
# type               house        unit
# council
# Ashfield       79.500000  109.666667
# Botany Bay     29.000000   56.000000
# Burwood              NaN   43.000000
# Canada Bay     15.000000         NaN
# Canterbury     36.000000   15.000000
# Lane Cove            NaN  220.000000
# Leichhardt    225.000000         NaN
# Marrickville   81.285714   87.333333
# Randwick             NaN   53.000000
# Rockdale       17.000000         NaN
# Ryde                 NaN  139.000000
# Sydney         55.666667  158.400000

# %% [markdown]
# Note that ```NaN``` implies that there is no data here

# %% [markdown]
# The default ```aggfunc``` is ```avg``` but we could use other functions such as ```np.sum```

# %%
pd.pivot_table(df, index=['type'],aggfunc=np.sum)
# Out:
#        distance_to_CBD  sold       value
# type
# house            131.7  1384  20493258.0
# unit             125.6  2171  11714781.0

# %% [markdown]
# Use ```margins=True``` to show the total numbers

# %%
pd.pivot_table(df, index=['type','council'], aggfunc=np.sum, margins=True)
# Out:
#                     distance_to_CBD    sold       value
# type  council
# house Ashfield                 15.2   159.0   2203829.0
#       Botany Bay                8.2    29.0   1090744.0
#       Canada Bay                9.2    15.0   1036064.0
#       Canterbury                9.1    36.0   1066214.0
#       Leichhardt                5.2   225.0   1076623.0
#       Marrickville             47.2   569.0   6953373.0
#       Rockdale                  9.9    17.0    839676.0
#       Sydney                   27.7   334.0   6226735.0
# unit  Ashfield                 21.7   329.0   1779935.0
#       Botany Bay                8.2    56.0    484487.0
#       Burwood                   8.4    43.0    605927.0
#       Canterbury                9.1    15.0    593081.0
#       Lane Cove                 7.0   220.0    611207.0
#       Marrickville             39.3   524.0   3557482.0
#       Randwick                  5.2    53.0    577814.0
#       Ryde                      7.9   139.0    572923.0
#       Sydney                   18.8   792.0   2931925.0
# All                           257.3  3555.0  32208039.0

# %% [markdown]
# We should use avg for *value* but sum for *sold*, and we do not want to see *distance_to_CBD* for now

# %%
pd.pivot_table(df, index=['council','suburb'], 
               columns=['type'], 
               values=['sold', 'value'], 
               aggfunc={'sold':np.sum, 'value':np.mean}, 
               margins=True)
# Out:
#                                   value                            sold  \
# type                              house       unit          All   house
# council      suburb
# Ashfield     Ashfield         1123787.0  575096.00   849441.500   110.0
#              Haberfield             NaN  573347.00   573347.000     NaN
#              Summer Hill      1080042.0  631492.00   855767.000    49.0
# Botany Bay   Eastlakes        1090744.0  484487.00   787615.500    29.0
# Burwood      Croydon                NaN  605927.00   605927.000     NaN
# Canada Bay   Mortlake         1036064.0        NaN  1036064.000    15.0
# Canterbury   Hurlstone Park   1066214.0  593081.00   829647.500    36.0
# Lane Cove    Lane Cove North        NaN  611207.00   611207.000     NaN
# Leichhardt   Leichhardt       1076623.0        NaN  1076623.000   225.0
# Marrickville Dulwich Hill           NaN  622141.00   622141.000     NaN
#              Enmore           1079403.0  607195.00   843299.000    58.0
#              Lewisham               NaN  569889.00   569889.000     NaN
#              Marrickville      994026.0  552713.00   773369.500   191.0
#              Petersham        1122372.0  610890.00   866631.000    82.0
#              St Peters         920169.0        NaN   920169.000    50.0
#              Stanmore         1070242.0  594654.00   832448.000   108.0
#              Sydenham          845771.0        NaN   845771.000    21.0
#              Tempe             921390.0        NaN   921390.000    59.0
# Randwick     Centennial Park        NaN  577814.00   577814.000     NaN
# Rockdale     Turrella          839676.0        NaN   839676.000    17.0
# Ryde         Gladesville            NaN  572923.00   572923.000     NaN
# Sydney       Alexandria             NaN  617024.00   617024.000     NaN
#              Chippendale      1060415.0        NaN  1060415.000    31.0
#              Darlington       1062426.0        NaN  1062426.000    32.0
#              Elizabeth Bay          NaN  615967.00   615967.000     NaN
#              Erskineville     1005107.0        NaN  1005107.000    84.0
#              Newtown          1044330.0  559175.00   801752.500   166.0
#              Potts Point            NaN  565141.00   565141.000     NaN
#              Rushcutters Bay        NaN  574618.00   574618.000     NaN
#              Waterloo          937316.0        NaN   937316.000    11.0
#              Zetland          1117141.0        NaN  1117141.000    10.0
# All                           1024662.9  585739.05   805200.975  1384.0
#
#
# type                            unit     All
# council      suburb
# Ashfield     Ashfield          228.0   338.0
#              Haberfield         13.0    13.0
#              Summer Hill        88.0   137.0
# Botany Bay   Eastlakes          56.0    85.0
# Burwood      Croydon            43.0    43.0
# Canada Bay   Mortlake            NaN    15.0
# Canterbury   Hurlstone Park     15.0    51.0
# Lane Cove    Lane Cove North   220.0   220.0
# Leichhardt   Leichhardt          NaN   225.0
# Marrickville Dulwich Hill      143.0   143.0
#              Enmore             15.0    73.0
#              Lewisham           20.0    20.0
#              Marrickville      225.0   416.0
#              Petersham          69.0   151.0
#              St Peters           NaN    50.0
#              Stanmore           52.0   160.0
#              Sydenham            NaN    21.0
#              Tempe               NaN    59.0
# Randwick     Centennial Park    53.0    53.0
# Rockdale     Turrella            NaN    17.0
# Ryde         Gladesville       139.0   139.0
# Sydney       Alexandria        211.0   211.0
#              Chippendale         NaN    31.0
#              Darlington          NaN    32.0
#              Elizabeth Bay     182.0   182.0
#              Erskineville        NaN    84.0
#              Newtown           104.0   270.0
#              Potts Point       217.0   217.0
#              Rushcutters Bay    78.0    78.0
#              Waterloo            NaN    11.0
#              Zetland             NaN    10.0
# All                           2171.0  3555.0

# %% [markdown]
# # Advanced Filtering over Pivot Table

# %% [markdown]
# We firstly build a pivot table

# %%
table = pd.pivot_table(df, index=['council'], columns=['type'], values=['sold'], aggfunc=np.sum, margins=True)
table
# Out:
#                 sold
# type           house    unit     All
# council
# Ashfield       159.0   329.0   488.0
# Botany Bay      29.0    56.0    85.0
# Burwood          NaN    43.0    43.0
# Canada Bay      15.0     NaN    15.0
# Canterbury      36.0    15.0    51.0
# Lane Cove        NaN   220.0   220.0
# Leichhardt     225.0     NaN   225.0
# Marrickville   569.0   524.0  1093.0
# Randwick         NaN    53.0    53.0
# Rockdale        17.0     NaN    17.0
# Ryde             NaN   139.0   139.0
# Sydney         334.0   792.0  1126.0
# All           1384.0  2171.0  3555.0

# %% [markdown]
# We can just look at data from one city

# %%
table.query('council==["Randwick"]')
# Out:
#           sold
# type     house  unit   All
# council
# Randwick   NaN  53.0  53.0

# %% [markdown]
# We can also specify multiple values

# %%
table.query('council==["Rockdale","Lane Cove"]')
# Out:
#            sold
# type      house   unit    All
# council
# Lane Cove   NaN  220.0  220.0
# Rockdale   17.0    NaN   17.0

# %% [markdown]
# Note: we can not query a pivot table from the ```columns```. So you should put *item* in ```index``` if you want to query it.

# %% [markdown]
# ### Plot the data using plot.ly
#
# Before you can execute the code below, you need to install `plotly`, register a free account with them, and create a profile that contains your own API key. See https://plot.ly/python/getting-started/

# %%
plot_table = table[:-1]  # get rid of ALL

# %%
plot_table.sold.house
# Out:
# council
# Ashfield        159.0
# Botany Bay       29.0
# Burwood           NaN
# Canada Bay       15.0
# Canterbury       36.0
# Lane Cove         NaN
# Leichhardt      225.0
# Marrickville    569.0
# Randwick          NaN
# Rockdale         17.0
# Ryde              NaN
# Sydney          334.0
# Name: house, dtype: float64

# %%
table.sold.house
# Out:
# council
# Ashfield         159.0
# Botany Bay        29.0
# Burwood            NaN
# Canada Bay        15.0
# Canterbury        36.0
# Lane Cove          NaN
# Leichhardt       225.0
# Marrickville     569.0
# Randwick           NaN
# Rockdale          17.0
# Ryde               NaN
# Sydney           334.0
# All             1384.0
# Name: house, dtype: float64

# %%
plot_table.index
# Out:
# Index(['Ashfield', 'Botany Bay', 'Burwood', 'Canada Bay', 'Canterbury',
#        'Lane Cove', 'Leichhardt', 'Marrickville', 'Randwick', 'Rockdale',
#        'Ryde', 'Sydney'],
#       dtype='object', name='council')

# %%
trace1 = go.Bar(
    x=plot_table.index,
    y=plot_table.sold.house,
    name='House'
)
trace2 = go.Bar(
    x=plot_table.index,
    y=plot_table.sold.unit,
    name='Unit'
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='group'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='pandas-notebook-plot2')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~weiwangoz/4.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Exercise
#
# Perform some analysis that interests you using the Sydney Acution Data at https://auction-results.domain.com.au/Proofed/PDF/Sydney_Domain.pdf
