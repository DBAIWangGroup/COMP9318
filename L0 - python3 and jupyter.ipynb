# %% [markdown]
# # Setting up your `python` environment

# %% [markdown]
# We will be using `python 3` and `ipython`/`jupyter` extensively in this course. You need to set up the correct `python` environment first. Below are some instructions in a Mac OS X 10.11 environment. You should be able to adapt it to other environments -- try Google if any problem.

# %% [markdown]
# ## Installing `anaconda` and `jupyter`

# %% [markdown]
# 1. Download and install the `anaconda` installation package (for `python 3.6`) at https://www.continuum.io/downloads
# 2. Create a `py36` virtual environment by `conda create -n py36 python=3.6 anaconda`. See more at http://conda.pydata.org/docs/using/envs.html
# 3. Activiate `py36` (or put it on your `~/.bashrc`): `source activate py36`
# 4. To install a new package in an environment, switch to it and use `conda install -n PACKAGENAME` or `pip install PACKAGENAME`
# 5. Install `jupyter` by `conda install jupyter`

# %% [markdown]
# ### Test you installation

# %% [markdown]
# ```
# % python -V
# Python 3.6.3 :: Anaconda ...
# % ipython -V
# 6.1.0
# % jupyter notebook
# ```
#
#
# The last command shall open up a new page in your browser. Also check if you click the "new" button, there is a "python 3" choice under the 'notebooks'.

# %% [markdown]
# ## Using `jupyter`

# %% [markdown]
# Start with simple tutorial: https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/index.html
#
# Press `h` (you may need to press `ESC` first) to learn a few important keyboard shortcuts, e.g.,
#
# * `SHIFT+RETURN`
# * `A`, `B`, `X`
# * `ESC`
# * `ESC m`: to change the current cell to a `markdown` cell,
# * selecting multiple lines + `TAB` (indent them) / `Cmd + /` (block comment).
# * Note that mouse selection = copying to clipboard (sometimes annoying).
#
# Read the syntax of `markdown` at http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Working%20With%20Markdown%20Cells.html and try it out by yourself.
#
# It also can display maths symbols/equations, e.g., $e^{ix} = cos(x) + i \cdot sin(x)$.
#
# $$ P \implies Q  \qquad \equiv \qquad P \lor \neg Q $$
#
# Try out cells with simple python code (or try the following cell in this notebook).
#
# **Tips**:
#
# * Recommended browser: firefox (Chrome has issues rendering maths fonts/equations)
# * Your code may run into an infinite loop and you may HAVE TO kill the browser. So use a decent session manager for your browser.

# %%
import random

n = 10
data = [random.randint(1, 10) for _ in range(n)]
data # this print out the variable's content
# Out:
# [1, 10, 10, 7, 9, 10, 5, 3, 5, 9]

# %%
import string
import sys
import urllib.request
from bs4 import BeautifulSoup
from pprint import pprint

def get_page(url):
    try :
        web_page = urllib.request.urlopen(url).read()
        soup = BeautifulSoup(web_page, 'html.parser')
        return soup
    except urllib2.HTTPError :
        print("HTTPERROR!")
    except urllib2.URLError :
        print("URLERROR!")
        
def get_titles(sp):
    i = 1
    papers = sp.find_all('div', {'class' : 'data'})
    for paper in papers:
        title = paper.find('span', {'class' : 'title'} )
        print("Paper {}:\t{}".format(i, title.get_text()))
        i += 1

# %%
sp = get_page('http://dblp.uni-trier.de/pers/hd/m/Manning:Christopher_D=')

# %%
get_titles(sp)
# Out:
# Paper 1:	Universal Dependency Parsing from Scratch.
# Paper 2:	Simpler but More Accurate Semantic Dependency Parsing.
# Paper 3:	Learning to Summarize Radiology Findings.
# Paper 4:	Universal Dependency Parsing from Scratch.
# Paper 5:	Textual Analogy Parsing: What's Shared and What's Compared among Analogous Facts.
# Paper 6:	Semi-Supervised Sequence Modeling with Cross-View Training.
# Paper 7:	Graph Convolution over Pruned Dependency Trees Improves Relation Extraction.
# Paper 8:	HotpotQA: A Dataset for Diverse, Explainable Multi-hop Question Answering.
# Paper 9:	Sentences with Gapping: Parsing and Reconstructing Elided Predicates.
# Paper 10:	Compositional Attention Networks for Machine Reasoning.
# Paper 11:	Sentences with Gapping: Parsing and Reconstructing Elided Predicates.
# Paper 12:	Simpler but More Accurate Semantic Dependency Parsing.
# Paper 13:	CoQA: A Conversational Question Answering Challenge.
# Paper 14:	Textual Analogy Parsing: What's Shared and What's Compared among Analogous Facts.
# Paper 15:	Learning to Summarize Radiology Findings.
# Paper 16:	Semi-Supervised Sequence Modeling with Cross-View Training.
# Paper 17:	HotpotQA: A Dataset for Diverse, Explainable Multi-hop Question Answering.
# Paper 18:	Graph Convolution over Pruned Dependency Trees Improves Relation Extraction.
# Paper 19:	Arc-swift: A Novel Transition System for Dependency Parsing.
# Paper 20:	Naturalizing a Programming Language via Interactive Learning.
# Paper 21:	Get To The Point: Summarization with Pointer-Generator Networks.
# Paper 22:	Gapping Constructions in Universal Dependencies v2.
# Paper 23:	CoNLL 2017 Shared Task: Multilingual Parsing from Raw Text to Universal Dependencies.
# Paper 24:	Stanford's Graph-based Neural Dependency Parser at the CoNLL 2017 Shared Task.
# Paper 25:	A Copy-Augmented Sequence-to-Sequence Architecture Gives Good Performance on Task-Oriented Dialogue.
# Paper 26:	Position-aware Attention and Supervised Data Improve Slot Filling.
# Paper 27:	Importance sampling for unbiased on-demand evaluation of knowledge base population.
# Paper 28:	Key-Value Retrieval Networks for Task-Oriented Dialogue.
# Paper 29:	TinkerBell: Cross-lingual Cold-Start Knowledge Base Construction.
# Paper 30:	Stanford at TAC KBP 2017: Building a Trilingual Relational Knowledge Graph.
# Paper 31:	A Copy-Augmented Sequence-to-Sequence Architecture Gives Good Performance on Task-Oriented Dialogue.
# Paper 32:	SceneSeer: 3D Scene Design with Natural Language.
# Paper 33:	Get To The Point: Summarization with Pointer-Generator Networks.
# Paper 34:	Naturalizing a Programming Language via Interactive Learning.
# Paper 35:	Arc-swift: A Novel Transition System for Dependency Parsing.
# Paper 36:	Key-Value Retrieval Networks for Task-Oriented Dialogue.
# Paper 37:	Combining Natural Logic and Shallow Reasoning for Question Answering.
# Paper 38:	A Fast Unified Model for Parsing and Sentence Understanding.
# Paper 39:	A Thorough Examination of the CNN/Daily Mail Reading Comprehension Task.
# Paper 40:	Improving Coreference Resolution by Learning Entity-Level Distributed Representations.
# Paper 41:	Achieving Open Vocabulary Neural Machine Translation with Hybrid Word-Character Models.
# Paper 42:	Learning Language Games through Interaction.
# Paper 43:	Compression of Neural Machine Translation Models via Pruning.
# Paper 44:	Deep Reinforcement Learning for Mention-Ranking Coreference Models.
# Paper 45:	A comparison of Named-Entity Disambiguation and Word Sense Disambiguation.
# Paper 46:	Universal Dependencies v1: A Multilingual Treebank Collection.
# Paper 47:	Enhanced English Universal Dependencies: An Improved Representation for Natural Language Understanding Tasks.
# Paper 48:	Evaluating Word Embeddings Using a Representative Suite of Practical Tasks.
# Paper 49:	Understanding Human Language: Can NLP and Deep Learning Help?
# Paper 50:	Stanford at TAC KBP 2016: Sealing Pipeline Leaks and Understanding Chinese.
# Paper 51:	Evaluating the word-expert approach for Named-Entity Disambiguation.
# Paper 52:	A Fast Unified Model for Parsing and Sentence Understanding.
# Paper 53:	Achieving Open Vocabulary Neural Machine Translation with Hybrid Word-Character Models.
# Paper 54:	Improving Coreference Resolution by Learning Entity-Level Distributed Representations.
# Paper 55:	Learning Language Games through Interaction.
# Paper 56:	A Thorough Examination of the CNN/Daily Mail Reading Comprehension Task.
# Paper 57:	Compression of Neural Machine Translation Models via Pruning.
# Paper 58:	Deep Reinforcement Learning for Mention-Ranking Coreference Models.
# Paper 59:	Deep Biaffine Attention for Neural Dependency Parsing.
# Paper 60:	Natural language translation at the intersection of AI and HCI.
# Paper 61:	Computational Linguistics and Deep Learning.
# Paper 62:	Natural Language Translation at the Intersection of AI and HCI.
# Paper 63:	Learning Distributed Word Representations for Natural Logic Reasoning.
# Paper 64:	Software Document Terminology Recognition.
# Paper 65:	Text to 3D Scene Generation with Rich Lexical Grounding.
# Paper 66:	Leveraging Linguistic Structure For Open Domain Information Extraction.
# Paper 67:	Robust Subgraph Generation Improves Abstract Meaning Representation Parsing.
# Paper 68:	Entity-Centric Coreference Resolution with Model Stacking.
# Paper 69:	Improved Semantic Representations From Tree-Structured Long Short-Term Memory Networks.
# Paper 70:	Generating Semantically Precise Scene Graphs from Textual Descriptions for Improved Image Retrieval.
# Paper 71:	Deep Neural Language Models for Machine Translation.
# Paper 72:	Forum77: An Analysis of an Online Health Forum Dedicated to Addiction Recovery.
# Paper 73:	Invited Talk: The Case for Universal Dependencies.
# Paper 74:	Does Universal Dependencies need a parsing representation? An investigation of English.
# Paper 75:	A large annotated corpus for learning natural language inference.
# Paper 76:	Effective Approaches to Attention-based Neural Machine Translation.
# Paper 77:	Learning Distributed Representations for Multilingual Text Sequences.
# Paper 78:	Bilingual Word Representations with Monolingual Quality in Mind.
# Paper 79:	Distributed Representations of Words to Guide Bootstrapped Entity Classifiers.
# Paper 80:	Tree-Structured Composition in Neural Networks without Tree-Structured Architectures.
# Paper 81:	On-the-Job Learning with Bayesian Decision Theory.
# Paper 82:	Bootstrapped Self Training for Knowledge Base Population.
# Paper 83:	Improved Semantic Representations From Tree-Structured Long Short-Term Memory Networks.
# Paper 84:	Text to 3D Scene Generation with Rich Lexical Grounding.
# Paper 85:	Robust Subgraph Generation Improves Abstract Meaning Representation Parsing.
# Paper 86:	On-the-Job Learning with Bayesian Decision Theory.
# Paper 87:	Tree-structured composition in neural networks without tree-structured architectures.
# Paper 88:	Effective Approaches to Attention-based Neural Machine Translation.
# Paper 89:	A large annotated corpus for learning natural language inference.
# Paper 90:	Research and applications: Induced lexico-syntactic patterns improve information extraction from online medical forums.
# Paper 91:	Cross-lingual Projected Expectation Regularization for Weakly Supervised Learning.
# Paper 92:	Grounded Compositional Semantics for Finding and Describing Images with Sentences.
# Paper 93:	The Stanford CoreNLP Natural Language Processing Toolkit.
# Paper 94:	Robust Logistic Regression using Shift Parameters.
# Paper 95:	Faster Phrase-Based Decoding by Refining Feature State.
# Paper 96:	Two Knives Cut Better Than One: Chinese Word Segmentation with Dual Decomposition.
# Paper 97:	Word Segmentation of Informal Arabic with Domain Adaptation.
# Paper 98:	TransPhoner: automated mnemonic keyword generation.
# Paper 99:	Improved Pattern Learning for Bootstrapped Entity Extraction.
# Paper 100:	NaturalLI: Natural Logic Inference for Common Sense Reasoning.
# Paper 101:	A Fast and Accurate Dependency Parser using Neural Networks.
# Paper 102:	Glove: Global Vectors for Word Representation.
# Paper 103:	Combining Distant and Partial Supervision for Relation Extraction.
# Paper 104:	Modeling Biological Processes for Reading Comprehension.
# Paper 105:	Human Effort and Machine Learnability in Computer Aided Translation.
# Paper 106:	Learning Spatial Knowledge for Text to 3D Scene Generation.
# Paper 107:	A Gold Standard Dependency Corpus for English.
# Paper 108:	Event Extraction Using Distant Supervision.
# Paper 109:	Universal Stanford dependencies: A cross-linguistic typology.
# Paper 110:	Global Belief Recursive Neural Networks.
# Paper 111:	Simple MAP Inference via Low-Rank Relaxations.
# Paper 112:	Learning Distributed Representations for Structured Output Prediction.
# Paper 113:	On being the right scale: sizing large collections of 3D models.
# Paper 114:	Predictive translation memory: a mixed-initiative system for human language translation.
# Paper 115:	Phrasal: A Toolkit for New Directions in Statistical Machine Translation.
# Paper 116:	Stanford University's Submissions to the WMT 2014 Translation Task.
# Paper 117:	An Empirical Comparison of Features and Tuning for Phrase-based Machine Translation.
# Paper 118:	Recursive Neural Networks for Learning Logical Semantics.
# Paper 119:	Learning Distributed Word Representations for Natural Logic Reasoning.
# Paper 120:	Parsing Models for Identifying Multiword Expressions.
# Paper 121:	Effective Bilingual Constraints for Semi-Supervised Learning of Named Entity Recognizers.
# Paper 122:	Fast and Adaptive Online Training of Feature-Rich Translation Models.
# Paper 123:	Parsing with Compositional Vector Grammars.
# Paper 124:	Joint Word Alignment and Bilingual Named Entity Recognition Using Dual Decomposition.
# Paper 125:	The efficacy of human post-editing for language translation.
# Paper 126:	Better Word Representations with Recursive Neural Networks for Morphology.
# Paper 127:	Philosophers are Mortal: Inferring the Truth of Unseen Facts.
# Paper 128:	More Constructions, More Genres: Extending Stanford Dependencies.
# Paper 129:	Feature Noising for Log-Linear Structured Prediction.
# Paper 130:	Bilingual Word Embeddings for Phrase-Based Machine Translation.
# Paper 131:	Recursive Deep Models for Semantic Compositionality Over a Sentiment Treebank.
# Paper 132:	Learning Biological Processes with Global Constraints.
# Paper 133:	Fast dropout training.
# Paper 134:	Topic Model Diagnostics: Assessing Domain Relevance via Topical Alignment.
# Paper 135:	Learning a Product of Experts with Elitist Lasso.
# Paper 136:	Effect of Non-linear Deep Architecture in Sequence Labeling.
# Paper 137:	Deep Learning for NLP (without Magic).
# Paper 138:	Named Entity Recognition with Bilingual Constraints.
# Paper 139:	Reasoning With Neural Tensor Networks for Knowledge Base Completion.
# Paper 140:	Zero-Shot Learning Through Cross-Modal Transfer.
# Paper 141:	SUTime: Evaluation in TempEval-3.
# Paper 142:	Feature-Rich Phrase-based Translation: Stanford University's Submission to the WMT 2013 Translation Task.
# Paper 143:	Positive Diversity Tuning for Machine Translation System Combination.
# Paper 144:	Proceedings of the Workshop on Continuous Vector Space Models and their Compositionality, CVSM@ACL 2013, Sofia, Bulgaria, August 9, 2013.
# Paper 145:	Stanford's 2013 KBP System.
# Paper 146:	Learning New Facts From Knowledge Bases With Neural Tensor Networks and Semantic Word Vectors.
# Paper 147:	Zero-Shot Learning Through Cross-Modal Transfer.
# Paper 148:	Robust Logistic Regression using Shift Parameters.
# Paper 149:	Cross-lingual Pseudo-Projected Expectation Regularization for Weakly Supervised Learning.
# Paper 150:	Relaxations for inference in restricted Boltzmann machines.
# Paper 151:	Combining joint models for biomedical event extraction.
# Paper 152:	Did It Happen? The Pragmatic Complexity of Veridicality Assessment.
# Paper 153:	"Without the clutter of unimportant words": Descriptive keyphrases for text visualization.
# Paper 154:	Deep Learning for NLP (without Magic).
# Paper 155:	Baselines and Bigrams: Simple, Good Sentiment and Topic Classification.
# Paper 156:	Improving Word Representations via Global Context and Multiple Word Prototypes.
# Paper 157:	Accurate Unsupervised Joint Named-Entity Extraction from Unaligned Parallel Text.
# Paper 158:	Termite: visualization techniques for assessing textual topic models.
# Paper 159:	Interpretation and trust: designing model-driven visualizations for text analysis.
# Paper 160:	Short message communications: users, topics, and in-language processing.
# Paper 161:	Multi-instance Multi-label Learning for Relation Extraction.
# Paper 162:	Learning Constraints for Consistent Timeline Extraction.
# Paper 163:	Probabilistic Finite State Machines for Regression-based MT Evaluation.
# Paper 164:	Semantic Compositionality through Recursive Matrix-Vector Spaces.
# Paper 165:	SUTime: A library for recognizing and normalizing time expressions.
# Paper 166:	Entity Clustering Across Languages.
# Paper 167:	Parsing Time: Learning to Interpret Time Expressions.
# Paper 168:	Convolutional-Recursive Deep Learning for 3D Object Classification.
# Paper 169:	SPEDE: Probabilistic Edit Distance Metrics for MT Evaluation.
# Paper 170:	Customizing an Information Extraction System to a New Domain.
# Paper 171:	Event Extraction as Dependency Parsing.
# Paper 172:	Event Extraction as Dependency Parsing for BioNLP 2011.
# Paper 173:	Model Combination for Event Extraction in BioNLP 2011.
# Paper 174:	Part-of-Speech Tagging from 97% to 100%: Is It Time for Some Linguistics?
# Paper 175:	Natural Language Processing Tools for the Digital Humanities.
# Paper 176:	Semi-Supervised Recursive Autoencoders for Predicting Sentiment Distributions.
# Paper 177:	Multiword Expression Identification with Tree Substitution Grammars: A Parsing tour de force with French.
# Paper 178:	Risk analysis for intellectual property litigation.
# Paper 179:	Parsing Natural Scenes and Natural Language with Recursive Neural Networks.
# Paper 180:	Analyzing the Dynamics of Research by Extracting Key Aspects of Scientific Papers.
# Paper 181:	Partially labeled topic models for interpretable text mining.
# Paper 182:	Dynamic Pooling and Unfolding Recursive Autoencoders for Paraphrase Detection.
# Paper 183:	Veridicality and Utterance Understanding.
# Paper 184:	TopicFlow Model: Unsupervised Learning of Topic-specific Influences of Hyperlinked Documents.
# Paper 185:	Spectral Chinese Restaurant Processes: Nonparametric Clustering Based on Similarities.
# Paper 186:	Proceedings of the Fifteenth Conference on Computational Natural Language Learning, CoNLL 2011, Portland, Oregon, USA, June 23-24, 2011.
# Paper 187:	Stanford-UBC Entity Linking at TAC-KBP, Again.
# Paper 188:	Stanford's Distantly-Supervised Slot-Filling System.
# Paper 189:	Which words are hard to recognize? Prosodic, lexical, and disfluency factors that increase speech recognition error rates.
# Paper 190:	"Was It Good? It Was Provocative." Learning the Meaning of Scalar Adjectives.
# Paper 191:	Hierarchical Joint Learning: Improving Joint Parsing and Named Entity Recognition with Non-Jointly Labeled Data.
# Paper 192:	Better Arabic Parsing: Baselines, Evaluations, and Analysis.
# Paper 193:	Probabilistic Tree-Edit Models with Structured Latent Variables for Textual Entailment and Question Answering.
# Paper 194:	Viterbi Training Improves Unsupervised Dependency Parsing.
# Paper 195:	A Multi-Pass Sieve for Coreference Resolution.
# Paper 196:	Parsing to Stanford Dependencies: Trade-offs between Speed and Accuracy.
# Paper 197:	Phrasal: A Statistical Machine Translation Toolkit for Exploring New Model Features.
# Paper 198:	Subword Variation in Text Message Classification.
# Paper 199:	The Best Lexical Metric for Phrase-Based Statistical MT System Optimization.
# Paper 200:	Ensemble Models for Dependency Parsing: Cheap and Good?
# Paper 201:	Improved Models of Distortion Cost for Statistical Machine Translation.
# Paper 202:	Accurate Non-Hierarchical Phrase-Based Translation.
# Paper 203:	Stanford-UBC Entity Linking at TAC-KBP.
# Paper 204:	A Simple Distant Supervision Approach for the TAC-KBP Slot Filling Task.
# Paper 205:	Measuring machine translation quality as semantic equivalence: A metric based on entailment features.
# Paper 206:	Multi-word expressions in textual inference: Much ado about nothing?
# Paper 207:	Presupposed Content and Entailments in Natural Language Inference.
# Paper 208:	Robust Machine Translation Evaluation with Entailment Features.
# Paper 209:	Quadratic-Time Dependency Parsing for Machine Translation.
# Paper 210:	Nested Named Entity Recognition.
# Paper 211:	Labeled LDA: A supervised topic model for credit attribution in multi-labeled corpora.
# Paper 212:	An extended model of natural logic.
# Paper 213:	Joint Parsing and Named Entity Recognition.
# Paper 214:	Hierarchical Bayesian Domain Adaptation.
# Paper 215:	Discriminative Reordering with Chinese Grammatical Relations Features.
# Paper 216:	Random Walks for Text Semantic Similarity.
# Paper 217:	WikiWalk: Random walks on Wikipedia for Semantic Relatedness.
# Paper 218:	Machine Translation Evaluation with Textual Entailment Features.
# Paper 219:	Disambiguating "DE" for Chinese-English Machine Translation.
# Paper 220:	Clustering the tagged web.
# Paper 221:	Proceedings of the 2009 Workshop on Applied Textual Inference, TextInfer@ACL 2009, Suntec, Singapore, August 6, 2009.
# Paper 222:	Stanford-UBC at TAC-KBP.
# Paper 223:	Introduction to information retrieval.
# Paper 224:	A Global Joint Model for Semantic Role Labeling.
# Paper 225:	Enforcing Transitivity in Coreference Resolution.
# Paper 226:	Which Words Are Hard to Recognize? Prosodic, Lexical, and Disfluency Factors that Increase ASR Error Rates.
# Paper 227:	Efficient, Feature-based, Conditional Random Field Parsing.
# Paper 228:	Finding Contradictions in Text.
# Paper 229:	The Stanford Typed Dependencies Representation.
# Paper 230:	Modeling Semantic Containment and Exclusion in Natural Language Inference.
# Paper 231:	Studying the History of Ideas Using Topic Models.
# Paper 232:	Legal Docket Classification: Where Machine Learning Stumbles.
# Paper 233:	A Phrase-Based Alignment Model for Natural Language Inference.
# Paper 234:	A Simple and Effective Hierarchical Phrase Reordering Model.
# Paper 235:	Lexicon Schemas and Related Data Models: when Standards Meet Users.
# Paper 236:	Regularization and Search for Minimum Error Rate Training.
# Paper 237:	Optimizing Chinese Word Segmentation for Machine Translation Performance.
# Paper 238:	Proceedings of the workshop on Cross-Framework and Cross-Domain Parser Evaluation@COLING 2008, Manchester, UK, August 23, 2008.
# Paper 239:	Deciding Entailment and Contradiction with Stochastic and Edit Distance-based Alignment.
# Paper 240:	Robust Graph Alignment Methods for Textual Inference and Machine Reading.
# Paper 241:	Learning Alignments and Leveraging Natural Logic.
# Paper 242:	The Infinite Tree.
# Paper 243:	Natural Logic for Textual Inference.
# Paper 244:	Regularization, adaptation, and non-independent features improve hidden conditional random fields for phone classification.
# Paper 245:	An Effective Two-Stage Model for Exploiting Non-Local Dependencies in Named Entity Recognition.
# Paper 246:	Unsupervised Discovery of a Statistical Verb Lexicon.
# Paper 247:	Solving the Problem of Cascading Errors: Approximate Bayesian Inference for Linguistic Annotation Pipelines.
# Paper 248:	Generating Typed Dependency Parses from Phrase Structure Parses.
# Paper 249:	Learning to recognize features of valid textual entailments.
# Paper 250:	Graphical Model Representations of Word Lattices.
# Paper 251:	Exploring the boundaries: gene and protein identification in biomedical text.
# Paper 252:	Natural language grammar induction with a generative constituent-context model.
# Paper 253:	Robust Textual Inference Via Learning and Abductive Reasoning.
# Paper 254:	Incorporating Non-local Information into Information Extraction Systems by Gibbs Sampling.
# Paper 255:	Unsupervised Learning of Field Segmentation Models for Information Extraction.
# Paper 256:	Joint Learning Improves Semantic Role Labeling.
# Paper 257:	A Conditional Random Field Word Segmenter for Sighan Bakeoff 2005.
# Paper 258:	Morphological features help POS tagging of unknown words across language varieties.
# Paper 259:	A Joint Model for Semantic Role Labeling.
# Paper 260:	Robust Textual Inference via Graph Matching.
# Paper 261:	Deep Dependencies from Context-Free Statistical Parsers: Correcting the Surface Dependency Approximation.
# Paper 262:	Corpus-Based Induction of Syntactic Structure: Models of Dependency and Constituency.
# Paper 263:	Exploiting Context for Biomedical Entity Recognition: From Syntax to the Web.
# Paper 264:	Language Learning: Beyond Thunderdome.
# Paper 265:	Using Feature Conjunctions Across Examples for Learning Pairwise Classifiers.
# Paper 266:	Max-Margin Parsing.
# Paper 267:	Verb Sense and Subcategorization: Using Joint Inference to Improve Performance on Complementary Task.
# Paper 268:	The Leaf Path Projection View of Parse Trees: Exploring String Kernels for HPSG Parse Selection.
# Paper 269:	Learning random walk models for inducing word dependency distributions.
# Paper 270:	Accurate Unlexicalized Parsing.
# Paper 271:	Is it Harder to Parse Chinese, or the Chinese Treebank?
# Paper 272:	Named Entity Recognition with Character-Level Models.
# Paper 273:	A Generative Model for Semantic Role Labeling.
# Paper 274:	Optimizing Local Probability Models for Statistical Parsing.
# Paper 275:	Spectral Learning.
# Paper 276:	Factored A* Search for Models over Sequences and Trees.
# Paper 277:	A* Parsing: Fast Exact Viterbi Parse Selection.
# Paper 278:	Optimization, Maxent Models, and Conditional Estimation without Magic.
# Paper 279:	Feature-Rich Part-of-Speech Tagging with a Cyclic Dependency Network.
# Paper 280:	Log-Linear Models for Label Ranking.
# Paper 281:	Extrapolation methods for accelerating PageRank computations.
# Paper 282:	A Generative Constituent-Context Model for Improved Grammar Induction.
# Paper 283:	The LinGO Redwoods Treebank: Motivation and Preliminary Applications.
# Paper 284:	Feature Selection for a Rich HPSG Grammar Using Decision Trees.
# Paper 285:	Conditional Structure versus Conditional Estimation in NLP Models.
# Paper 286:	Extentions to HMM-based Statistical Word Alignment Models.
# Paper 287:	Interpreting and Extending Classical Agglomerative Clustering Algorithms using a Model-Based approach.
# Paper 288:	From Instance-level Constraints to Space-Level Constraints: Making the Most of Prior Knowledge in Data Clustering.
# Paper 289:	Fast Exact Inference with a Factored Model for Natural Language Parsing.
# Paper 290:	Combining Heterogeneous Classifiers for Word Sense Disambiguation.
# Paper 291:	Foundations of statistical natural language processing.
# Paper 292:	Kirrkirr: Software for Browsing and Visual Exploration of a Structured Warlpiri Dictionary.
# Paper 293:	Parsing with Treebank Grammars: Empirical Bounds, Theoretical Models, and the Structure of the Penn Treebank.
# Paper 294:	Distributional phrase structure induction.
# Paper 295:	Parsing and Hypergraphs.
# Paper 296:	Natural Language Grammar Induction Using a Constituent-Context Model.
# Paper 297:	Combining Heterogeneous Classifiers for Word-Sense Disambiguation.
# Paper 298:	What's related? Generalizing approaches to related articles in medicine.
# Paper 299:	Enriching the Knowledge Sources Used in a Maximum Entropy Part-of-Speech Tagger.
# Paper 300:	Linguistics in an Age of Engineering.
# Paper 301:	The segmentation problem in morphology learning.
# Paper 302:	Probabilistic Parsing Using Left Corner Language Models.
# Paper 303:	Automatic Acquisition of a Large Subcategorization Dictionary from Corpora.

# %% [markdown]
# ## Numpy

# %% [markdown]
# ## Exercise

# %% [markdown]
# 1. Compute the top-10 most frequently appearing words in the papers of the author.
#
# For Manning, the output should be:
#
# ```
# [('for', 109),
#  ('and', 63),
#  ('of', 50),
#  ('Learning', 40),
#  ('with', 37),
#  ('A', 33),
#  ('the', 30),
#  ('to', 26),
#  ('in', 25),
#  ('Machine', 22)]
# ```
#
# You may even be able to use the `wordcloud` package to generate the word cloud:

# %%
from IPython.display import Image
Image(filename="./asset/Christopher_Manning_wordcloud.png")
